# %%
# We have grayscale images, so while loading the images we will keep grayscale=True, if you have RGB images, you should set grayscale as False
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
from tqdm import tqdm
from keras.utils import to_categorical
from keras.models import load_model
from keras.preprocessing import image
import pandas as pd
import numpy as np
# Out:
# TensorFlow 1.x selected.
# 1.15.2
# Using TensorFlow backend.

# %%
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
test=pd.read_csv("/content/drive/My Drive/Colab Notebooks/results/inference_2_1.csv")

# %%
test_image = []
for i in tqdm(range(test.shape[0])):
    im_buf = test.values[i][0:]
    im_array = np.int8(np.reshape(im_buf, (78, 78))) 
    #img = image.load_img(train.iloc[:,1:].as_matrix().astype('str'), target_size=(64,64,1), color_mode='grayscale')
    img = image.img_to_array(im_array)
    img = img/255
    test_image.append(img)
X_test = np.array(test_image)
X_test = np.repeat(X_test, 3, -1)
# Out:
# 100%|██████████| 87/87 [00:00<00:00, 6003.20it/s]

# %%
model = load_model("/content/drive/My Drive/Colab Notebooks/model_letters_94.h5")

# %%
pred=model.predict(X_test)
for i in pred:
    print(i)
# Out:
# [1.0000000e+00 1.6664673e-19 8.4847410e-19 1.5477886e-18 2.1615897e-22
#  5.4002787e-16 8.5157500e-13 7.8470147e-11 6.2412933e-13 1.8543675e-20
#  1.8631181e-19 2.9641799e-17 6.0523846e-13 1.5691050e-13 1.4291624e-18
#  4.8574771e-18 2.2321031e-15 1.4170216e-10 3.0484780e-24 3.1710905e-23
#  2.7199217e-22 2.0414989e-30 1.2728951e-17 1.5630270e-16 3.9570914e-19
#  2.1618997e-25]
# [1.3184110e-09 7.8814967e-15 6.0849576e-16 3.4730021e-12 1.8537068e-15
#  1.5512736e-13 7.2268874e-10 2.7411386e-07 3.6133351e-12 2.3623900e-12
#  8.5412336e-14 5.1042611e-18 1.5826085e-10 9.9999976e-01 1.5158680e-16
#  6.7007672e-14 1.9812761e-10 7.9501449e-12 6.4435240e-14 2.0248132e-17
#  5.7669771e-14 5.4487148e-10 4.0296907e-08 1.4656389e-12 2.1827939e-14
#  6.2196405e-24]
# [3.6097354e-13 1.4335776e-08 3.3156460e-17 2.3397622e-11 3.2441735e-10
#  4.7644263e-12 8.1941351e-09 2.3291485e-10 7.1642725e-10 1.2303886e-11
#  9.9999917e-01 7.0681724e-11 7.6078814e-09 1.4521314e-12 4.8479397e-18
# ...

# %%
output=np.argmax(pred, axis=1)
output
# Out:
# array([ 0, 13, 10,  8,  8, 13, 13, 13, 13, 13, 15, 15, 15, 13, 13, 15, 15,
#        13, 13, 13, 13, 13, 13, 15, 13, 15, 15, 15, 13, 15, 10, 20, 12,  0,
#        17, 15, 13, 13, 15, 15, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13,
#        13, 15, 15, 15, 15, 15,  3,  0, 18, 13, 15, 13, 13, 13, 15, 15, 15,
#        13, 13, 15, 15, 15, 15, 15, 15, 13, 13, 15, 13, 13, 13, 15, 15, 15,
#        15, 15])

# %%
labels=pd.read_excel("/content/drive/My Drive/Colab Notebooks/results/Labels Inference.xlsx",index_col="Sr. No.")

# %%
labels.loc[0]
# Out:
# Labels1    A
# Name: 0, dtype: object

# %%
for i in output:
  print(labels.iloc[i].values)
# Out:
# ['A']
# ['N']
# ['K']
# ['I']
# ['I']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['P']
# ['P']
# ['P']
# ['N']
# ['N']
# ['P']
# ['P']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['P']
# ['N']
# ['P']
# ['P']
# ['P']
# ['N']
# ['P']
# ['K']
# ['U']
# ['M']
# ['A']
# ['R']
# ['P']
# ['N']
# ['N']
# ['P']
# ['P']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['N']
# ['P']
# ['P']
# ['P']
# ['P']
# ['P']
# ['D']
# ['A']
# ['S']
# ['N']
# ['P']
# ['N']
# ['N']
# ['N']
# ['P']
# ['P']
# ['P']
# ['N']
# ['N']
# ['P']
# ['P']
# ['P']
# ['P']
# ['P']
# ['P']
# ['N']
# ['N']
# ['P']
# ['N']
# ['N']
# ['N']
# ['P']
# ['P']
# ['P']
# ['P']
# ['P']

# %%
train1=pd.read_csv("/content/drive/My Drive/Colab Notebooks/results/train/train.csv")

# %%
train1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f88614b18060> in <module>()
# ----> 1 train1.head()
#
# NameError: name 'train1' is not defined
