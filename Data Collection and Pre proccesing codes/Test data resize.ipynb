# %%
letters=[]
for i in range(65,91):
    letters.append(chr(i))
# letters

# %%
#DataFlair - Load the data and extract features for each sound file
def resize_img(read_path,target_path):
    from PIL import Image
    import os
    import glob
    import shutil
    import numpy as np 

    from matplotlib.pyplot import imshow
    from matplotlib import image
    from matplotlib import pyplot
    import cv2
    for folder in range(0,26):
        tar_dir=target_path+"\\"+letters[folder]+"\\"
        if not os.path.exists(tar_dir):
            os.makedirs(tar_dir) 
    for folder in range(0,26):
        count=0
        curr_dir=read_path+"\\"+letters[folder]
        print(curr_dir)
        tar_dir=target_path+"\\"+letters[folder]+"\\"
        #print(tar_dir)
        for file in glob.glob(curr_dir+"\\*.jpg"):
            count+=1
            image = Image.open(file)
            #print('here')
            #img = cv2.imread(file)
            #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # convert to grayscale

# threshold to get just the signature
            #retval, thresh_gray = cv2.threshold(gray, thresh=100, maxval=255, type=cv2.THRESH_BINARY)


            img_resized = image.resize((28,28))
            img_resized = np.array(img_resized)
            #thresh = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,21,2)
            #print(img_resized.size)
            #if (count==1):
             #   pyplot.imshow(img_resized)
            #print(tar_dir)
            cv2.imwrite(tar_dir+str(count)+".png",img_resized)

# %%
resize_img(r"C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters",
          r"C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized")
# Out:
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters\A
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# C:\Users\Rahul\Desktop\Capstone\OCR\data\model\test\test_letters_resized\A\
# 784
# ...
