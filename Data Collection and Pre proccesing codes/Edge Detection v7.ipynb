# %%
from scipy.stats import mode
import time
import statistics
import operator
import cv2
import numpy as np
import pandas as pd
import os 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_data(read_path,filter_count=0,filter_type='m'):
    #Load the image in black and white (0 - b/w, 1 - color).
    img = cv2.imread(read_path, 0)
    #img=img[60:20,-20:-20]     # im.crop((left, top, right, bottom)) 
    print(img.shape)

    #Get the height and width of the image.
    h, w = img.shape[:2]

    
    #Invert the image to be white on black for compatibility with findContours function.
    imgray = 255 - img
    #ret, imgray = cv2.threshold(imgray, 80, 255, cv2.THRESH_BINARY_INV)
    size=9+2*filter_count
#     print(size)
    if (filter_type=='m'):
        print("m")
        
        rects=[]
        rects1=[]
        rects2=[]
        rects3=[]
        rects4=[]
        rects5=[]
        rects6=[]
    
        # rects1 imp
        kernel = np.ones((2,5),np.uint8)
        imgray1 = cv2.dilate(imgray,kernel,iterations = 1)
        kernel = np.ones((5,2),np.uint8)
        imgray1 = cv2.dilate(imgray1,kernel,iterations = 1)
        thresh1 = cv2.adaptiveThreshold(imgray1, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh.
        contours, hierarchy = cv2.findContours(thresh1, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects1 = [cv2.boundingRect(cnt) for cnt in contours]


        # rects2 imp
        imgray2 = cv2.blur(imgray,(7,3))
        thresh2 = cv2.adaptiveThreshold(imgray2, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh2, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects2 = [cv2.boundingRect(cnt) for cnt in contours]


        # rects3 imp
        imgray3 = cv2.blur(imgray,(3,7))
        thresh3 = cv2.adaptiveThreshold(imgray3, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh3, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects3 = [cv2.boundingRect(cnt) for cnt in contours]


        #rects4 imp
        kernel = np.ones((2,7),np.uint8)
        imgray4 = cv2.dilate(imgray,kernel,iterations = 1)
        thresh4 = cv2.adaptiveThreshold(imgray4, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh4, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects4 = [cv2.boundingRect(cnt) for cnt in contours]


        #rects5 imp
        kernel = np.ones((7,2),np.uint8)
        imgray5 = cv2.dilate(imgray,kernel,iterations = 1)
        thresh5 = cv2.adaptiveThreshold(imgray5, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh5, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects5 = [cv2.boundingRect(cnt) for cnt in contours]
        
        thresh6 = cv2.adaptiveThreshold(imgray, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh6, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects6 = [cv2.boundingRect(cnt) for cnt in contours]
        
        # rects7 imp
        kernel = np.ones((4,4),np.uint8)
        imgray7 = cv2.dilate(imgray,kernel,iterations = 1)
        kernel = np.ones((4,4),np.uint8)
        imgray7 = cv2.dilate(imgray7,kernel,iterations = 1)
        thresh7 = cv2.adaptiveThreshold(imgray7, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh7, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects7 = [cv2.boundingRect(cnt) for cnt in contours]
        
        
    else:
        print("g")
        
        rects=[]
        rects1=[]
        rects2=[]
        rects3=[]
        rects4=[]
        rects5=[]
        rects6=[]
        
        # rects1 imp
        kernel = np.ones((2,5),np.uint8)
        imgray1 = cv2.dilate(imgray,kernel,iterations = 1)
        kernel = np.ones((5,2),np.uint8)
        imgray1 = cv2.dilate(imgray1,kernel,iterations = 1)
        thresh1 = cv2.adaptiveThreshold(imgray1, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh1, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects1 = [cv2.boundingRect(cnt) for cnt in contours]


        # rects2 imp
        imgray2 = cv2.blur(imgray,(7,3))
        thresh2 = cv2.adaptiveThreshold(imgray2, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh2, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects2 = [cv2.boundingRect(cnt) for cnt in contours]


        # rects3 imp
        imgray3 = cv2.blur(imgray,(3,7))
        thresh3 = cv2.adaptiveThreshold(imgray3, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh3, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects3 = [cv2.boundingRect(cnt) for cnt in contours]


        #rects4 imp
        kernel = np.ones((2,7),np.uint8)
        imgray4 = cv2.dilate(imgray,kernel,iterations = 1)
        thresh4 = cv2.adaptiveThreshold(imgray4, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh4, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects4 = [cv2.boundingRect(cnt) for cnt in contours]


        #rects5 imp
        kernel = np.ones((7,2),np.uint8)
        imgray5 = cv2.dilate(imgray,kernel,iterations = 1)
        thresh5 = cv2.adaptiveThreshold(imgray5, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh5, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects5 = [cv2.boundingRect(cnt) for cnt in contours]
        
        
        thresh6 = cv2.adaptiveThreshold(imgray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh6, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects6 = [cv2.boundingRect(cnt) for cnt in contours]
        
        # rects7 imp
        kernel = np.ones((4,4),np.uint8)
        imgray7 = cv2.dilate(imgray,kernel,iterations = 1)
        kernel = np.ones((4,4),np.uint8)
        imgray7 = cv2.dilate(imgray7,kernel,iterations = 1)
        thresh7 = cv2.adaptiveThreshold(imgray7, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size,2)
        #Find all the contours in thresh. 
        contours, hierarchy = cv2.findContours(thresh7, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
        rects7 = [cv2.boundingRect(cnt) for cnt in contours]
        
        
    print(len(rects),len(rects1),len(rects2),len(rects3),len(rects4),len(rects5),len(rects6),len(rects7))



    for i in rects1:
        if (i[2]>55 and i[3]>55 and i[2]<80 and i[3]<80 and i not in rects):
            rects.append(i)
            
    for i in rects2:
        if (i[2]>55 and i[3]>55 and i[2]<80 and i[3]<80 and i not in rects):
            rects.append(i)

    for i in rects3:
        if (i[2]>55 and i[3]>55 and i[2]<80 and i[3]<80 and i not in rects):
            rects.append(i)

    for i in rects4:
        if (i[2]>55 and i[3]>55 and i[2]<80 and i[3]<80 and i not in rects):
            rects.append(i)

    for i in rects5:
        if (i[2]>55 and i[3]>55 and i[2]<80 and i[3]<80 and i not in rects):
            rects.append(i)

    for i in rects6:
        if (i[2]>55 and i[3]>55 and i[2]<80 and i[3]<80 and i not in rects):
            rects.append(i)

    for i in rects7:
        if (i[2]>55 and i[3]>55 and i[2]<80 and i[3]<80 and i not in rects):
            rects.append(i)
            
            
    print(len(rects),"here")
    rects_final=rects.copy()
    for i in range(0,len(rects)-1):
        try:
            for j in range(i+1,len(rects)):
                if (abs(rects[i][0] - rects[j][0]) < 10 and abs(rects[i][1] - rects[j][1]) < 10):
                    #if (rects[i][2]  < rects[j][2] and rects[i][3] < rects[j][3]):
                    rects_final.remove(rects[j])

        except:
            continue
            

    rects_final_2=rects_final.copy()
    
    #Calculate the combined bounding rectangle points.
    try:
        top_x = min([x for (x, y, w, h) in rects_final_2])
        top_y = min([y for (x, y, w, h) in rects_final_2])
        bottom_x = max([x+w for (x, y, w, h) in rects_final_2])
        bottom_y = max([y+h for (x, y, w, h) in rects_final_2])
        h_mode = mode([h for (x, y, w, h) in rects_final_2])[0]
    
#     print("h_mode",h_mode)
    
        n=int(((bottom_y-top_y)/int(h_mode)))
    except:
        print("error")
        n=1
        h_mode=1
        bottom_y=1
        print (len(rects_final_2))
    temp=[]
    b = [[] for i in range(0, n+5)]
    for j in range (1,n+5):
        for i in rects_final_2:
            x=i[0]
            y=i[1]
            w=i[2]
            h=i[3]
            if ((y > bottom_y-h_mode*j-h_mode/2.1) and (i not in temp)):
                b[j].append(i)
                temp.append(i)
            b[j]=sorted(b[j],key=lambda x:(-x[0]))
    return(imgray,b)

# %%
df=pd.read_excel(r"C:\Users\Rahul\Desktop\Capstone\OCR\scan copy\Labels.xlsx",index_col="Sr. No.")

# %%
read_path=r"C:\Users\Rahul\Desktop\Capstone\OCR\scan copy\scan_19_1"+"\\"
class_path=r'C:\Users\Rahul\Desktop\Capstone\OCR\scan copy\results_19_1'+'\\'
imgsave=1
for folder in range(1,621):
    class_folder=class_path+str(df.loc[folder,"Labels2"])
    if not os.path.exists(class_folder):
        os.makedirs(class_folder) 
m=g=0
c=[]

for i in range(1,30):
    if (m==10 and g==10 and len(c)!=620):
        print("Skipped image is ", (i-1))
    m=g=0
    c=[]
    while((len(c)!=620) and (m!=10 or g!=10)):
        c=[]
        if (m<10 and g==0):
            m+=1
            imgray,b=get_data(read_path+str(i)+".jpg",filter_count=m,filter_type='m')
            #print(m)
        elif (m==10 and g<10):
            g+=1
            imgray,b=get_data(read_path+str(i)+".jpg",filter_count=g,filter_type='g')
            #print(g)  
        for row in b:
            for box in row:
                try:
                    w=box[2]
                    h=box[3]
                    #print(w)
                    if ((w>55 and w<80) and (h>55 and h <80)):
                        c.append(box)
                        #print(c)
                except:
                    continue
                    
        print(len(c))
        if (len(c)==620):
            print("here")
            count=1
            for box in c:
                x=box[0]
                y=box[1]
                w=box[2]
                h=box[3]
                class_folder=class_path+str(df.loc[count,"Labels2"])
                cv2.imwrite(class_folder+'\\'+str(i)+" img "+str(imgsave)+".jpg",imgray[y:y+h,x:x+w])
                imgsave+=1
#                 time.sleep(0.005)
                count+=1
# Out:
# (3507, 2497)
# m
# 0 22858 13576 10127 30097 30018 46715 21332
# 3618 here
# 624
# (3507, 2497)
# m
# 0 19043 12309 10267 23818 23836 39813 17296
# 3875 here
# 624
# (3507, 2497)
# m
# 0 14846 11292 9921 19536 18890 34482 13983
# 4141 here
# 622
# (3507, 2497)
# m
# 0 11871 10302 9386 16276 15031 30503 11161
# 4261 here
# 623
# (3507, 2497)
# m
# 0 10326 9510 8741 14381 12867 27950 9596
# 4294 here
# 621
# (3507, 2497)
# m
# 0 9359 8847 8156 13125 11588 26455 8557
# 4316 here
# 622
# (3507, 2497)
# m
# 0 8403 8332 7575 12223 10462 25402 7656
# 4313 here
# 622
# (3507, 2497)
# m
# 0 7758 7869 7146 11518 9712 24631 7072
# 4311 here
# 622
# (3507, 2497)
# m
# 0 7314 7573 6766 10882 9157 24146 6552
# 4318 here
# 625
# (3507, 2497)
# m
# 0 6939 7276 6406 10544 8580 23755 6239
# 4320 here
# 628
# (3507, 2497)
# g
# 0 34884 10505 5946 54941 56426 74723 34563
# 3855 here
# 623
# (3507, 2497)
# g
# 0 30957 11937 6577 47355 46260 67732 29318
# 3759 here
# 623
# (3507, 2497)
# g
# 0 28382 12620 7594 40933 39360 62980 26200
# 3571 here
# 624
# (3507, 2497)
# g
# 0 25926 12912 8422 35798 34212 58827 23488
# 3628 here
# 624
# (3507, 2497)
# g
# 0 23227 13028 9118 31693 29845 54774 20846
# 3781 here
# 624
# (3507, 2497)
# g
# 0 20404 12792 9502 27967 26083 50367 18393
# 3938 here
# 624
# (3507, 2497)
# g
# 0 17830 12536 9517 24580 22574 45952 16226
# 4065 here
# 623
# (3507, 2497)
# g
# 0 15803 11997 9588 21785 19796 41561 14437
# 4176 here
# 622
# (3507, 2497)
# g
# 0 14207 11481 9346 19637 17663 38073 13062
# 4250 here
# 622
# (3507, 2497)
# g
# 0 12959 10857 9011 17983 16101 35044 12036
# 4272 here
# 622
# Skipped image is  1
# (3507, 2497)
# m
# 0 14555 8176 6108 17719 17078 22732 14005
# 3680 here
# 620
# here
# (3507, 2505)
# m
# 0 14377 8058 6526 18121 17000 22768 13739
# 3639 here
# 620
# here
# (3507, 2489)
# m
# 0 19809 10846 8389 26230 27055 41031 18848
# 3714 here
# 621
# (3507, 2489)
# m
# 0 16284 9749 8272 20503 20907 34297 15055
# 3933 here
# 621
# (3507, 2489)
# m
# 0 12711 8906 7969 16504 16084 29220 11848
# 4097 here
# 621
# (3507, 2489)
# m
# 0 9944 8111 7559 13391 12764 25348 9262
# 4235 here
# 621
# (3507, 2489)
# m
# 0 8549 7647 7133 11641 10953 23015 7887
# 4275 here
# 621
# (3507, 2489)
# m
# 0 7545 7066 6605 10492 9762 21649 6981
# 4289 here
# 621
# (3507, 2489)
# m
# 0 6793 6561 6080 9706 8879 20732 6182
# 4298 here
# 621
# (3507, 2489)
# m
# 0 6134 6132 5556 9178 8020 19994 5610
# 4302 here
# 621
# (3507, 2489)
# m
# 0 5697 5829 5262 8604 7487 19427 5197
# 4308 here
# 621
# (3507, 2489)
# m
# 0 5398 5503 4942 8272 7088 19081 4894
# 4293 here
# 622
# (3507, 2489)
# g
# 0 31393 8626 5414 49474 53138 68556 31988
# 4030 here
# 622
# (3507, 2489)
# g
# 0 27565 9695 5795 41622 42854 61184 26654
# 3847 here
# 622
# (3507, 2489)
# g
# 0 24831 10351 6602 35391 35713 56245 23240
# 3729 here
# 620
# here
# (3507, 2482)
# m
# 0 18778 10479 8629 24609 25797 40851 17625
# 3813 here
# 620
# here
# (3507, 2497)
# m
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-40684af22618> in <module>
#      18         if (m<10 and g==0):
#      19             m+=1
# ---> 20             imgray,b=get_data(read_path+str(i)+".jpg",filter_count=m,filter_type='m')
#      21             #print(m)
#      22         elif (m==10 and g<10):
#
# <ipython-input-5-55620d8bc608> in get_data(read_path, filter_count, filter_type)
#      45
#      46         # rects3 imp
# ---> 47         imgray3 = cv2.blur(imgray,(3,7))
#      48         thresh3 = cv2.adaptiveThreshold(imgray3, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,size,2)
#      49         #Find all the contours in thresh. In your case the 3 and the additional strike
#
# KeyboardInterrupt:
